# %%
import os
import torch
import gruut
from trainer import Trainer, TrainerArgs
from TTS.tts.configs.tacotron2_config import Tacotron2Config
from TTS.config import BaseAudioConfig, BaseDatasetConfig
from TTS.tts.configs.fast_speech_config import FastSpeechConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.models.forward_tts import ForwardTTS
from TTS.tts.utils.speakers import SpeakerManager
from TTS.tts.utils.text.tokenizer import TTSTokenizer
from TTS.utils.audio import AudioProcessor
from TTS.tts.models.tacotron2 import Tacotron2

# Check if CUDA is available
print(torch.cuda.is_available())
USE_CUDA = torch.cuda.is_available()

output_path = "/srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1"

if not os.path.exists(output_path):
    os.makedirs(output_path)

# Create a BaseDatasetConfig object
dataset_config = BaseDatasetConfig(formatter="custom_formatter", meta_file_train="train.csv", path=os.path.join(output_path))

# Load the dataset using your custom formatter
train_samples, eval_samples = load_tts_samples([dataset_config], eval_split=True)

audio_config = BaseAudioConfig(
    sample_rate=24000,
    do_trim_silence=True,
    trim_db=23.0,
    signal_norm=False,
    mel_fmin=0.0,
    mel_fmax=8000,
    spec_gain=1.0,
    log_func="np.log",
    ref_level_db=20,
    preemphasis=0.0,
)

# Configure your Tacotron2 model
config = Tacotron2Config(
    batch_size=32,
    eval_batch_size=16,
    num_loader_workers=4,
    num_eval_loader_workers=4,
    precompute_num_workers=4,
    run_eval=True,
    test_delay_epochs=-1,
    epochs=100,
    use_phonemes=True,
    phonemizer="gruut",
    phoneme_language="es-es",
    phoneme_cache_path=os.path.join(output_path, "phoneme_cache2"),
    print_step=25,
    print_eval=False,
    mixed_precision=True,
    output_path=output_path,
    datasets=[dataset_config],
    use_speaker_embedding=True,
    min_text_len=0,
    max_text_len=500,
    min_audio_len=100000,  # Adjust this value based on your requirements
    max_audio_len=400000,  # Adjust this value based on your requirements
)

config.audio.fft_size = 2048
config.audio.win_length = 1200
config.audio.hop_length = 256
config.audio.num_mels = 80

ap = AudioProcessor.init_from_config(audio_config)

# Initialize the TTSTokenizer
tokenizer, config = TTSTokenizer.init_from_config(config)

# Initialize the gruut phonemizer

# Initialize speaker manager
speaker_manager = SpeakerManager()
speaker_manager.set_ids_from_data(train_samples + eval_samples, parse_key="speaker_name")
config.num_speakers = speaker_manager.num_speakers

# Initialize Tacotron2 model
model = Tacotron2(config, ap, tokenizer, speaker_manager=speaker_manager)
trainer = Trainer(
    TrainerArgs(), config, output_path, model=model, train_samples=train_samples, eval_samples=eval_samples
)

# Training loop with phonemized text printing

# Train the model
trainer.fit()
# Out:
# False
#  | > Found 168523 files in /srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1
#  > Setting up Audio Processor...
#  | > sample_rate:24000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:23.0
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Init speaker_embedding layer.
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: True
#  | > Precision: fp16
#  | > Num. of CPUs: 8
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 54321
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=/srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1/run-November-03-2023_09+39PM-5cf4ea1
#
#  > Model has 32649330 parameters
#  > `speakers.pth` is saved to /srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1/run-November-03-2023_09+39PM-5cf4ea1/speakers.pth.
#  > `speakers_file` is updated in the config.json.
#  > EPOCH: 0/100
#  --> /srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1/run-November-03-2023_09+39PM-5cf4ea1
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: es-es
# 		| > phoneme backend: gruut
# | > Number of instances : 166838
#  > TRAINING (2023-11-03 21:41:08)
#  | > Preprocessing samples
#  | > Max text length: 305
#  | > Min text length: 0
#  | > Avg text length: 137.913679273466
#  |
#  | > Max audio length: 399382.0
#  | > Min audio length: 100821.0
#  | > Avg audio length: 245005.40084841967
#  | > Num. instances discarded samples: 32942
#  | > Batch group size: 0.
# {'text': 'mer l el estudiante se desmayó', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}{'text': 'decidle que habían dado aviso a ordwinter de mi viaje a inglaterra', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'los moros tienen una fiesta de caballos que llama la fantasía', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
# {'text': 'rica y abundante de todas las cosas necesarias para la vida humana', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'has amado la justicia y aborrecido la maldad', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'has amado la justicia y aborrecido la maldad', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'has amado la justicia y aborrecido la maldad', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'has amado la justicia y aborrecido la maldad', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'pero que en amaneciendo había de dar sobre la garza', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'pero que en amaneciendo había de dar sobre la garza', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'pero que en amaneciendo había de dar sobre la garza', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'pero que en amaneciendo había de dar sobre la garza', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'ena un liset omnibus ad ire coring tum', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'ena un liset omnibus ad ire coring tum', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'ena un liset omnibus ad ire coring tum', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'ena un liset omnibus ad ire coring tum', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
#
#
#
# {'text': 'llegamos en poco tiempo a saint-denis', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'llegamos en poco tiempo a saint-denis', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'llegamos en poco tiempo a saint-denis', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'llegamos en poco tiempo a saint-denis', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
#
#
#
# {'text': 'despreciamos lo espiritual cuando se opone a lo temporal', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'despreciamos lo espiritual cuando se opone a lo temporal', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'despreciamos lo espiritual cuando se opone a lo temporal', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'despreciamos lo espiritual cuando se opone a lo temporal', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
#
#
# {'text': 'y el cabecero dijo escucho y obedesco', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'y el cabecero dijo escucho y obedesco', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'y el cabecero dijo escucho y obedesco', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'y el cabecero dijo escucho y obedesco', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'por eso digo que debo de estar enferma cuando me persiguen visiones y vestiglos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'por eso digo que debo de estar enferma cuando me persiguen visiones y vestiglos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'por eso digo que debo de estar enferma cuando me persiguen visiones y vestiglos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'por eso digo que debo de estar enferma cuando me persiguen visiones y vestiglos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'porque por la mayor parte será por graves culpas a mi parecer', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'porque por la mayor parte será por graves culpas a mi parecer', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'porque por la mayor parte será por graves culpas a mi parecer', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'porque por la mayor parte será por graves culpas a mi parecer', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'el cual está echado puro en el cáliz de su hira', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'el cual está echado puro en el cáliz de su hira', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
# {'text': 'el cual está echado puro en el cáliz de su hira', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'el cual está echado puro en el cáliz de su hira', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
# {'text': 'pasaron los años y camila fue llevada a un colegio', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'pasaron los años y camila fue llevada a un colegio', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'pasaron los años y camila fue llevada a un colegio', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
# {'text': 'pasaron los años y camila fue llevada a un colegio', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'y no habiendo querido reconocer su justa providencia en el primer aviso', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y no habiendo querido reconocer su justa providencia en el primer aviso', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y no habiendo querido reconocer su justa providencia en el primer aviso', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y no habiendo querido reconocer su justa providencia en el primer aviso', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'fosleván sintió que se le erizaban los cabellos', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'fosleván sintió que se le erizaban los cabellos', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'fosleván sintió que se le erizaban los cabellos', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'fosleván sintió que se le erizaban los cabellos', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'hasta el dolor de su padre parecía oprimirla con su peso', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'hasta el dolor de su padre parecía oprimirla con su peso', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'hasta el dolor de su padre parecía oprimirla con su peso', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'hasta el dolor de su padre parecía oprimirla con su peso', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
#
# {'text': 'seguía inmóvil y no soltaba a mompagnás', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'seguía inmóvil y no soltaba a mompagnás', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'seguía inmóvil y no soltaba a mompagnás', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'seguía inmóvil y no soltaba a mompagnás', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'y el espíritu y la esposa dicen ven', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'y el espíritu y la esposa dicen ven', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'y el espíritu y la esposa dicen ven', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'y el espíritu y la esposa dicen ven', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'del capítulo veintiséis', 'ph_hat': 'θeɾo', 'token_ids': array([116,   8,  82,  17]), 'token_ids_len': 4}{'text': 'del capítulo veintiséis', 'ph_hat': 'θeɾo', 'token_ids': array([116,   8,  82,  17]), 'token_ids_len': 4}{'text': 'del capítulo veintiséis', 'ph_hat': 'θeɾo', 'token_ids': array([116,   8,  82,  17]), 'token_ids_len': 4}{'text': 'del capítulo veintiséis', 'ph_hat': 'θeɾo', 'token_ids': array([116,   8,  82,  17]), 'token_ids_len': 4}
#
#
#
# {'text': 'pues todos te lo pedimos en actitud suplicante', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'pues todos te lo pedimos en actitud suplicante', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'pues todos te lo pedimos en actitud suplicante', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'pues todos te lo pedimos en actitud suplicante', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'qué diablo os movía a permanecer estáticos bajo la lluvia', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'qué diablo os movía a permanecer estáticos bajo la lluvia', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'qué diablo os movía a permanecer estáticos bajo la lluvia', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'qué diablo os movía a permanecer estáticos bajo la lluvia', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'capítulo decimonoveno de mendizabal de benito perez galdós', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'capítulo decimonoveno de mendizabal de benito perez galdós', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'capítulo decimonoveno de mendizabal de benito perez galdós', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}{'text': 'capítulo decimonoveno de mendizabal de benito perez galdós', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
#
#
#
# {'text': 'es indudable que algún tipo antropológico tendrá proponderancia en e tafe', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'es indudable que algún tipo antropológico tendrá proponderancia en e tafe', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'es indudable que algún tipo antropológico tendrá proponderancia en e tafe', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
#
# {'text': 'es indudable que algún tipo antropológico tendrá proponderancia en e tafe', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'que siempre gusta encontrar en los hombros de un amigo', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'que siempre gusta encontrar en los hombros de un amigo', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'que siempre gusta encontrar en los hombros de un amigo', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'que siempre gusta encontrar en los hombros de un amigo', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'ni recta ni aguileña ni italiana ni griega', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'ni recta ni aguileña ni italiana ni griega', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'ni recta ni aguileña ni italiana ni griega', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'ni recta ni aguileña ni italiana ni griega', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'así trocaron su gloria por la imagen de un buey que come hierba', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'así trocaron su gloria por la imagen de un buey que come hierba', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'así trocaron su gloria por la imagen de un buey que come hierba', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'así trocaron su gloria por la imagen de un buey que come hierba', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'ningún otro accidente vino a interrumpir después el curso de su dicha', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'ningún otro accidente vino a interrumpir después el curso de su dicha', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'ningún otro accidente vino a interrumpir después el curso de su dicha', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'ningún otro accidente vino a interrumpir después el curso de su dicha', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'e seguro que te llevo allá o una gran ilusión un gran desengaño', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'e seguro que te llevo allá o una gran ilusión un gran desengaño', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'e seguro que te llevo allá o una gran ilusión un gran desengaño', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'e seguro que te llevo allá o una gran ilusión un gran desengaño', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'llegó a una casa cuya puerta estaba entreabierta', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'llegó a una casa cuya puerta estaba entreabierta', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'llegó a una casa cuya puerta estaba entreabierta', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'llegó a una casa cuya puerta estaba entreabierta', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
# {'text': 'dicho esto entramos todos a la gruta', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'dicho esto entramos todos a la gruta', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'dicho esto entramos todos a la gruta', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'dicho esto entramos todos a la gruta', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'don diego era patriota', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'don diego era patriota', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'don diego era patriota', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'don diego era patriota', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
#
#
#
# {'text': 'el cual aunque viejo y fuera de moda estaba hacer viver', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'el cual aunque viejo y fuera de moda estaba hacer viver', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'el cual aunque viejo y fuera de moda estaba hacer viver', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'el cual aunque viejo y fuera de moda estaba hacer viver', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'aterrado quedó con el terrible trastorno que veía pintado en su semblante', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'aterrado quedó con el terrible trastorno que veía pintado en su semblante', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'aterrado quedó con el terrible trastorno que veía pintado en su semblante', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'aterrado quedó con el terrible trastorno que veía pintado en su semblante', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'los moros tienen una fiesta de caballos que llama la fantasía', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'los moros tienen una fiesta de caballos que llama la fantasía', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'los moros tienen una fiesta de caballos que llama la fantasía', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'los moros tienen una fiesta de caballos que llama la fantasía', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'a buen seguro que entre los palos de mi señor se hayen los míos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'a buen seguro que entre los palos de mi señor se hayen los míos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'a buen seguro que entre los palos de mi señor se hayen los míos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'a buen seguro que entre los palos de mi señor se hayen los míos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'ena el retrato de una joven ya próxima a ser mujer', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'ena el retrato de una joven ya próxima a ser mujer', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'ena el retrato de una joven ya próxima a ser mujer', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'ena el retrato de una joven ya próxima a ser mujer', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'a buen seguro que entre los palos de mi señor se hayen los míos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'ero ahora nadie les ganaba a darse pisto luciendo los trajes', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
# {'text': 'después bollos de aceite y lonjas de tocino con azúcar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'no faltaban hombres serios que quisieran casarse con ella', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'calma señoras mías calma que a mucha prisa  gran vagar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'calma señoras mías calma que a mucha prisa  gran vagar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'calma señoras mías calma que a mucha prisa  gran vagar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
# {'text': 'calma señoras mías calma que a mucha prisa  gran vagar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'se hace mucho frío se atan estrechamente contra el cuerpo sus partes naturales', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'se hace mucho frío se atan estrechamente contra el cuerpo sus partes naturales', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'se hace mucho frío se atan estrechamente contra el cuerpo sus partes naturales', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
#
# {'text': 'se hace mucho frío se atan estrechamente contra el cuerpo sus partes naturales', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'no te muevas no te muevas mira que si te cais te matas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'no te muevas no te muevas mira que si te cais te matas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'no te muevas no te muevas mira que si te cais te matas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'no te muevas no te muevas mira que si te cais te matas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'y que no tiene sino dos dientes en los costados de la boca', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y que no tiene sino dos dientes en los costados de la boca', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y que no tiene sino dos dientes en los costados de la boca', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'y que no tiene sino dos dientes en los costados de la boca', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'los republicanitos tenían en el un enemigo formidable', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'los republicanitos tenían en el un enemigo formidable', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'los republicanitos tenían en el un enemigo formidable', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'los republicanitos tenían en el un enemigo formidable', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'recibiréis órdenes escritas del oficial de servicio esta noche', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'recibiréis órdenes escritas del oficial de servicio esta noche', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'recibiréis órdenes escritas del oficial de servicio esta noche', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'recibiréis órdenes escritas del oficial de servicio esta noche', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
#
#
# {'text': 'y volviendo a entrar y estándo los tres solos  la hermosa dijo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'y volviendo a entrar y estándo los tres solos  la hermosa dijo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'y volviendo a entrar y estándo los tres solos  la hermosa dijo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'y volviendo a entrar y estándo los tres solos  la hermosa dijo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'las almas son como los ruiseñores todas quieren volar', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'las almas son como los ruiseñores todas quieren volar', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'las almas son como los ruiseñores todas quieren volar', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'las almas son como los ruiseñores todas quieren volar', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'laincalvo se acercó a doña aurora y le dijo señalando al grupo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'laincalvo se acercó a doña aurora y le dijo señalando al grupo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'laincalvo se acercó a doña aurora y le dijo señalando al grupo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'laincalvo se acercó a doña aurora y le dijo señalando al grupo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'no dejaban nunca de verse en las cámaras de los caballeros', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'no dejaban nunca de verse en las cámaras de los caballeros', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'no dejaban nunca de verse en las cámaras de los caballeros', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'no dejaban nunca de verse en las cámaras de los caballeros', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
#
# {'text': 'y fue su determinación matar con tósigo a isabela', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'y fue su determinación matar con tósigo a isabela', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'y fue su determinación matar con tósigo a isabela', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'y fue su determinación matar con tósigo a isabela', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'en tanto que esto se gasta yo escribirí a mi señorloo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'en tanto que esto se gasta yo escribirí a mi señorloo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'en tanto que esto se gasta yo escribirí a mi señorloo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'en tanto que esto se gasta yo escribirí a mi señorloo', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'has amado la justicia y aborrecido la maldad', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'ena el retrato de una joven ya próxima a ser mujer', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'calma señoras mías calma que a mucha prisa  gran vagar', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'babilonia violada rebaja a alejandro', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
# {'text': 'te aseguro  mamá que no sé como la aguanto aún', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'un cuero de vino que tenía quiero decir y toda la miel', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'un cuero de vino que tenía quiero decir y toda la miel', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'un cuero de vino que tenía quiero decir y toda la miel', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'un cuero de vino que tenía quiero decir y toda la miel', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'enarrar sumariamente s larga y penosa cruzada', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'enarrar sumariamente s larga y penosa cruzada', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'enarrar sumariamente s larga y penosa cruzada', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'enarrar sumariamente s larga y penosa cruzada', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'icogen últimamente la abertura', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'icogen últimamente la abertura', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'icogen últimamente la abertura', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}{'text': 'icogen últimamente la abertura', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
#
#
#
# {'text': 'y doblarás la sexta cortina delante de la faz del tabernáculo', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'y doblarás la sexta cortina delante de la faz del tabernáculo', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'y doblarás la sexta cortina delante de la faz del tabernáculo', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'y doblarás la sexta cortina delante de la faz del tabernáculo', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
#
# {'text': 'los sentimientos y visiones que me turban paréceme que no son míos', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'los sentimientos y visiones que me turban paréceme que no son míos', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'los sentimientos y visiones que me turban paréceme que no son míos', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'los sentimientos y visiones que me turban paréceme que no son míos', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'pero que en amaneciendo había de dar sobre la garza', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'se hace mucho frío se atan estrechamente contra el cuerpo sus partes naturales', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
# {'text': 'la mujer casada está atada a la ley mientras vive su marido', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'el proyecto le pareció al señorito de perlas', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'saludad a epeneto amado mío que es las primicias de aca', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'saludad a epeneto amado mío que es las primicias de aca', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'saludad a epeneto amado mío que es las primicias de aca', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'saludad a epeneto amado mío que es las primicias de aca', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
#
# {'text': 'las sabía que se estiraban para corresponder al crecimiento de su dueño', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'las sabía que se estiraban para corresponder al crecimiento de su dueño', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'las sabía que se estiraban para corresponder al crecimiento de su dueño', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'las sabía que se estiraban para corresponder al crecimiento de su dueño', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
#
#
# {'text': 'lo que más le molestaba era la limpieza', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'lo que más le molestaba era la limpieza', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'lo que más le molestaba era la limpieza', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}{'text': 'lo que más le molestaba era la limpieza', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
#
#
# {'text': 'la generación nueva no era clerófoga más que arratos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la generación nueva no era clerófoga más que arratos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la generación nueva no era clerófoga más que arratos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la generación nueva no era clerófoga más que arratos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'no te muevas no te muevas mira que si te cais te matas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'ena un liset omnibus ad ire coring tum', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
# {'text': 'y hitcliff se sentó al lado del fuego', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
# {'text': 'por risueños puntos de vista que ofrezcan las orillas del cua y del sil', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'dentro de una hora se habrán cumplido vuestros deseos', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'dentro de una hora se habrán cumplido vuestros deseos', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'dentro de una hora se habrán cumplido vuestros deseos', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'dentro de una hora se habrán cumplido vuestros deseos', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'estas obras se superponen unas a otras', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'estas obras se superponen unas a otras', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'estas obras se superponen unas a otras', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}{'text': 'estas obras se superponen unas a otras', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'as los que conforme al espíritu de las cosas del espíritu', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'as los que conforme al espíritu de las cosas del espíritu', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'as los que conforme al espíritu de las cosas del espíritu', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'as los que conforme al espíritu de las cosas del espíritu', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
#
#
# {'text': 'la gente se alegró pero sin abandonar su actitud calmosa', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la gente se alegró pero sin abandonar su actitud calmosa', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la gente se alegró pero sin abandonar su actitud calmosa', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'la gente se alegró pero sin abandonar su actitud calmosa', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'aquí anheley el onhero k', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}{'text': 'aquí anheley el onhero k', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}{'text': 'aquí anheley el onhero k', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}{'text': 'aquí anheley el onhero k', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}
#
#
#
# {'text': 'y que no tiene sino dos dientes en los costados de la boca', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'llegamos en poco tiempo a saint-denis', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
#
# {'text': 'no podres decir ahora como encontré en mi fuerzas bastantespara', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'adelante porque había dejado en tierra de guadalajara la división redatian', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'torné a guardar los papeles en mi cartera con un suspiro', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'torné a guardar los papeles en mi cartera con un suspiro', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'cuando se presenta la ocasión le decimos las verdades', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'ha pecado de muerte por el cual yo no digo que ruegue', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'el agravio puede venir de cualquier parte sin que afrente', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'el agravio puede venir de cualquier parte sin que afrente', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
# {'text': 'torné a guardar los papeles en mi cartera con un suspiro', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'torné a guardar los papeles en mi cartera con un suspiro', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'el agravio puede venir de cualquier parte sin que afrente', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'el agravio puede venir de cualquier parte sin que afrente', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'los aventarás y los llevará el viento y esparcirános el torbellino', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}{'text': 'los aventarás y los llevará el viento y esparcirános el torbellino', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
#
# {'text': 'los aventarás y los llevará el viento y esparcirános el torbellino', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'los aventarás y los llevará el viento y esparcirános el torbellino', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'despreciamos lo espiritual cuando se opone a lo temporal', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'los republicanitos tenían en el un enemigo formidable', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
#
# {'text': 'mer l el estudiante se desmayó', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}{'text': 'mer l el estudiante se desmayó', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}
#
# {'text': 'no faltaban hombres serios que quisieran casarse con ella', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}{'text': 'no faltaban hombres serios que quisieran casarse con ella', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
#
# {'text': 'te aseguro  mamá que no sé como la aguanto aún', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'te aseguro  mamá que no sé como la aguanto aún', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
# {'text': 'la mujer casada está atada a la ley mientras vive su marido', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}{'text': 'la mujer casada está atada a la ley mientras vive su marido', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'por risueños puntos de vista que ofrezcan las orillas del cua y del sil', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}{'text': 'por risueños puntos de vista que ofrezcan las orillas del cua y del sil', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
#
# {'text': 'adelante porque había dejado en tierra de guadalajara la división redatian', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}{'text': 'adelante porque había dejado en tierra de guadalajara la división redatian', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
#
# {'text': 'y el cabecero dijo escucho y obedesco', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'recibiréis órdenes escritas del oficial de servicio esta noche', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'cuando se presenta la ocasión le decimos las verdades', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'cuando se presenta la ocasión le decimos las verdades', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'habeis hecho en vuestra vida y aun en estos mismos días cosas admirables', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'mer l el estudiante se desmayó', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}
# {'text': 'no faltaban hombres serios que quisieran casarse con ella', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'te aseguro  mamá que no sé como la aguanto aún', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'la mujer casada está atada a la ley mientras vive su marido', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'por risueños puntos de vista que ofrezcan las orillas del cua y del sil', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'adelante porque había dejado en tierra de guadalajara la división redatian', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'verdad es que muchos tenían aún la loca esperanza de que llegasen socorros', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'cuando se presenta la ocasión le decimos las verdades', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'vuestro hasta la muerte el caballero de la triste figura', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'vuestro hasta la muerte el caballero de la triste figura', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'vuestro hasta la muerte el caballero de la triste figura', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'vuestro hasta la muerte el caballero de la triste figura', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
#
# {'text': 'mer l el estudiante se desmayó', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}
# {'text': 'al volver en mí no ha ceso de pensar en vosotros', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'al volver en mí no ha ceso de pensar en vosotros', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}{'text': 'al volver en mí no ha ceso de pensar en vosotros', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#
#
# ...
# {'text': 'estaba ahora perfectamente seguro de ello', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
# {'text': 'esto no es más que la obra de usd', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'viste el mar de terciopelo y el cielo profundo viste de duelo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'fija soy yo de don gómez que ngormás condado había', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'y el que ciega recibe salareo ya llega fruto para vida eterna', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'porque consagración de su dios tiene sobre su cabeza', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'dijo el capitán en cuanto que todos estuvieron reunidos', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'vivo o muerto nadie allí tenía miedo de venga', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'pues probaré una jugada nada más dijo dartañón', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'y que tuviesen más esta merced que todas las que me había hecho', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'todos ellos esperan en ti para que les de su comida a su tiempo', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'porque al que el envió a este vosotros no creéis', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'no se libra en mi vida o en mi muerte la victoria de los teucros', 'ph_hat': 'katoɾθe', 'token_ids': array([ 13,   4,  22,  17,  82, 116,   8]), 'token_ids_len': 7}
# {'text': 'ía aproximarse al ruido dulce y mesurado de sus pasos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'yo le conozco porque de el soy y el me envio', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'en el ocean en la caída de un meteoro', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'y dijo e liceo al rey de israel pon tu mano sobre el arco', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'dijo y vinieron langostas y pulgón sin número', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'estos necesitaron nuevos refuerzos necesitaron seis contra uno', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'sian avergonzados fallezcan los adversarios de mi alma', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'se estaba bien allí pero se temía vagamente la asfixia', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'el cual pidió determinó un año', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'la atención que se les dispensaba no podía hacer más a la güeña', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'no creo que en ningún país exista abnegación tan barata', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'vengo del cielo para apaciguar tu cólera si obedecieres', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'estoy seguro de que rogelín no le entró así ome', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'y vino un gran temor sobre todos los que lo oyeron', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'los aqueos de larga caballera acudieron a las naves', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'su traje identico sus costumbres y su índole las mismas siempre', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'si no te encuentro cuando vuelvas ancho te aseguro que me la pagas', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'y diciendo esto se levantó en pie y empuñó la espada', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'loque tuvo miedo y prometió buscar a iduna en joeteng', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'y mientras tanto los capitales bruchan mano pinta que pinta', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'la fiebre que la consumía hacía sus noches intranquilas', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'pero no me ha dicho usted quien es ese ingles ni en que se funda para pensar', 'ph_hat': 'dʝeθiseis', 'token_ids': array([  7, 105,   8, 116,  11,  21,   8,  11,  21]), 'token_ids_len': 9}
# {'text': 'y se les atribuya esta feliz circunstancia', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'la frente del príncipe descansa sobre las rodillas de su esposa', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'con el cual si viniere más presto os iré a ver', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'las dos y yo aquí de conversación olvidando las mil comisiones', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'solís la señora y pepillo estaban todavía en el comedor', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'no sabía dónde estaba retrocedía ciego ante tanta claridad', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'las hierbas me sustentan con sus raíces que arrango con mi mano', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'que adornaban las paredes de aquel centro de instrucción y recreo', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'el sol no te fatigará de día ni la luna de noche', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'doña catalina le lanzó una mirada furiosa', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'el primero es el sentimiento de la existencia moral o espiritual', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'la ferocidad brutal de estas circunstancias', 'ph_hat': 'θinko', 'token_ids': array([116,  11,  16,  13,  17]), 'token_ids_len': 5}
# {'text': 'el jefe de los rebeldes era demasiado astuto para que eso ocurriese', 'ph_hat': 'katoɾθe', 'token_ids': array([ 13,   4,  22,  17,  82, 116,   8]), 'token_ids_len': 7}
# {'text': 'y apartó aquel día los machos de cabrillo rayados y manchados', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'para defender a mi hijo todos los medios humanos e diapurar', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'abra usted esa puerta derríbela usted  señor pepe', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'silver gruñía cogiendo más que nunca sobre su moleta', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'pondrá luego su rostro para venir con el poder de todo su reino', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'pensó que si habrían equivocado de nombre al escribirle', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'ni uno solo de ellos lanzará en vano mi diestra contra los rútulos', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'suri me dijo que si quería iría a tierra en busca de agua', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'no confiéis en la violencia ni en la rapiña', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'porcia y lo repito bienvenido sean', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'en resumidas cuentas que el de luchana apretó el asedio', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'vosotros apuráis mis obras todas', 'ph_hat': 'kwatɾo', 'token_ids': array([13, 25,  4, 22, 82, 17]), 'token_ids_len': 6}
# {'text': 'mandó que le esperase fuera del espolón a las diez en punto', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'decirle que después que el se marchó volvió a subir uno de ellos', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'el sucesor de quintanar era soltero y no hubo conflicto', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'el reveses necio es el filósofo con sus andrazgos', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'en el vestíbulo había dos porteros cerca de una mesa de pino', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'vamos pues a concluir a todo trance', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'lo mismo se sirve del gotoso que del conquistador', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'pero no por esto disistió de su buen propósito', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'y su pie cecito se agitaba por debajo del vestido', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'pero de cuya alianza no permitía apartarse el honor a su futuro yerno', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'sus ojos eran un triunfo sus frescas mejillas sonreían', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'ya lo sé por eso quiero que usted me guíe', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'y murió también el rico y fue sepultado', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'dista me asimismo el scudo de tu salud', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'sabiendo que la prueba de vuestra fe obra paciencia', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'y quien como tu pueblo como israel en la tierra', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'os perdono la dijo el mal que me habéis hecho', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'vivis todos en mí la casa con su placidez con su blancura', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'he votado la fraternidad la concordia la aurora', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'se llamaba honorina levanaz como su ama', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'en el cuello del pecho un nuro toros', 'ph_hat': 'tɾes', 'token_ids': array([22, 82,  8, 21]), 'token_ids_len': 4}
# {'text': 'rafael hallándole perfecciones que de punto en punto le obligaban a mas amarla', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'y así creciendo el gusto por puntos vendrá a ser mayor en sus extremos', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'decían en parís que yo no vería brotar las hojas', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'como yo he estado hoy próximo a la muerte', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'ntas del alba chasqueando la lengua como si llamase a su perro', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'a habitaciones por donde le pasaron eran inmensas cuadras de elevado techo', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'iéronme ropa un caballo y medianamente enfermo les seguí', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'no decía claramente si la dama se había descubierto o no', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'era ya más celebre que scott wordsworkh', 'ph_hat': 'seis', 'token_ids': array([21,  8, 11, 21]), 'token_ids_len': 4}
# {'text': 'más a sus discípulos en particular declaraba todo', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'meñique sereno como una rosa abrió su gran saco de cuero', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'porque no me afrentó un enemigo lo cual habría soportado', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'mesía y su adversario temblaban como las ramas de los árboles que batía el viento', 'ph_hat': 'katoɾθe', 'token_ids': array([ 13,   4,  22,  17,  82, 116,   8]), 'token_ids_len': 7}
# {'text': 'de mis pies las hortigas que allí crecen las huellas tal vez guardan', 'ph_hat': 'doθe', 'token_ids': array([  7,  17, 116,   8]), 'token_ids_len': 4}
# {'text': 'su madre hijo se llamó la montiela que después de la camacha fue famosa', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'acordéme del juicio de cristo y vi cuándo nada era aquel', 'ph_hat': 'onθe', 'token_ids': array([ 17,  16, 116,   8]), 'token_ids_len': 4}
# {'text': 'y con mis ronquidos no podrá usted pegar los ojos en toda la noche', 'ph_hat': 'tɾeθe', 'token_ids': array([ 22,  82,   8, 116,   8]), 'token_ids_len': 5}
# {'text': 'en un extremo de la galería de cristales había una puerta', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'sin embargo apareció a poco seguido de su lacayo', 'ph_hat': 'otʃo', 'token_ids': array([17, 22, 86, 17]), 'token_ids_len': 4}
# {'text': 'que muchas veces el contarlas suele acrecentar la gravedad al cuento', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
# {'text': 'y los que pasaban le decían injurias meneando sus cabezas', 'ph_hat': 'dʝeθ', 'token_ids': array([  7, 105,   8, 116]), 'token_ids_len': 4}
# {'text': 'el baulito no se separó nunca de el', 'ph_hat': 'sʝete', 'token_ids': array([ 21, 105,   8,  22,   8]), 'token_ids_len': 5}
# {'text': 'no tenía duda que allí permanecería algún tiempo philiasfo', 'ph_hat': 'nwebe', 'token_ids': array([16, 25,  8,  5,  8]), 'token_ids_len': 5}
#  > Keyboard interrupt detected.
#  > Saving model before exiting...
#
#  > CHECKPOINT : /srv/storage/idmctal@storage1.nancy.grid5000.fr/2023/m2/adrelingyte/data/spanish/cml_tts_dataset_spanish_v0.1/run-November-03-2023_09+39PM-5cf4ea1/checkpoint_0.pth
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
